# %% [markdown]
# ### 使用PyTorch分類sklearn 20newgroups文章數據
#
# 這個notebook是基於下面的這篇教學文章
#
# [https://www.deborahmesquita.com/2017-11-05/how-pytorch-gives-the-big-picture-with-deep-learning](https://www.deborahmesquita.com/2017-11-05/how-pytorch-gives-the-big-picture-with-deep-learning)
#
# 原作者 Déborah Mesquita 的github
#
# [https://github.com/dmesquita/understanding_pytorch_nn](https://github.com/dmesquita/understanding_pytorch_nn)
#
# 在原本的文章裡作者使用3個newsgroups主題的資料來做分類。
#
# 在這裡我嘗試把newsgroups增加到14個來看看分類的效果如何。同時也對程式做了相關的小修改。
#
# 理論上如果能將文本進一步的預處理，像是去掉停用詞，做stemming跟lemmatization的處理。加上把BoW的詞頻向量換成word2vec相關的詞向量的話應該是可以提高預測能力一些的。

# %%
import torch
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.datasets import fetch_20newsgroups

# %%
x = torch.IntTensor([1,3,6])
y = torch.IntTensor([1,1,1])
result = x + y
print(result)
print(result.size())
# Out:
# tensor([2, 4, 7], dtype=torch.int32)
# torch.Size([3])

# %%
categories = ['comp.graphics',
 'comp.os.ms-windows.misc',
 'comp.sys.ibm.pc.hardware',
 'comp.sys.mac.hardware',
 'comp.windows.x',
 'misc.forsale',
 'rec.autos',
 'rec.motorcycles',
 'rec.sport.baseball',
 'rec.sport.hockey',
 'sci.med',
 'sci.space',
 'soc.religion.christian',
 'talk.politics.guns']

#categories = ["comp.graphics","sci.space","rec.sport.baseball"]

newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)
newsgroups_test = fetch_20newsgroups(subset='test', categories=categories)

print('total texts in train:', len(newsgroups_train.data))
print('total texts in test:', len(newsgroups_test.data))
# Out:
# total texts in train: 8242
# total texts in test: 5487

# %% [markdown]
# ### 把訓練文本跟測試文本分割成單詞然後存在Counter字典裡面

# %%
vocab = Counter()

for text in newsgroups_train.data:
    for word in text.split(' '):
        vocab[word.lower()]+=1

for text in newsgroups_test.data:
    for word in text.split(' '):
        vocab[word.lower()]+=1

total_words = len(vocab)
vocab
# Out:
# Counter({'from:': 13254,
#          '"jack': 5,
#          'previdi"': 3,
#          '<p00020@psilink.com>\nsubject:': 1,
#          're:': 8801,
#          'printing\nin-reply-to:': 1,
#          '<1qk2m5$1up@agate.berkeley.edu>\nnntp-posting-host:': 1,
#          '127.0.0.1\norganization:': 7,
#          'avoirdupois': 1,
#          'institute\nx-mailer:': 1,
#          'psilink-dos': 5,
#          '(3.4)\nlines:': 4,
#          '38\n\n>date:': 1,
#          '': 807949,
#          '15': 432,
#          'apr': 746,
#          '1993': 701,
#          '16:32:05': 1,
#          'gmt\n>from:': 2,
#          'cozzlab@garnet.berkeley.edu\n>\n>in': 1,
#          'article': 6888,
#          '<1993apr15.053905.16811@sarah.albany.edu>': 2,
#          'me9574@albnyvms.bitnet': 2,
#          'writes:\n>\n>[advertises': 1,
#          'his': 3832,
#          'printing': 100,
#          'business]\n>\n>oh,': 1,
#          'dear.': 9,
#          'let': 895,
#          'me': 5025,
#          'be': 16824,
#          'the': 126577,
#          'first': 2273,
#          'on': 19054,
#          'my': 9348,
#          'block.\n>\n>you': 1,
#          'have': 17266,
#          'just': 5035,
#          'violated': 21,
#          'one': 6537,
#          'of': 61170,
#          'major': 500,
#          'shibboleths': 2,
#          'usenet': 207,
#          'groups:\n': 2,
#          '^^^^^^^^^^^\n': 1,
#          '\tnit:': 1,
#          'is': 38324,
#          'he': 6296,
#          'unable': 103,
#          'to': 65966,
#          'type': 647,
#          "'h'": 6,
#          'in': 37692,
#          'this': 16004,
#          'word?': 3,
#          ";-)\n\n>you're": 1,
#          'not': 14515,
#          'supposed': 291,
#          'use': 3746,
#          'a': 59334,
#          'newsgroup': 234,
#          'plug': 129,
#          'your': 6452,
#          'own': 1253,
#          'commercial\n>enterprise': 1,
#          '(of': 80,
#          '_any_': 16,
#          'kind;': 2,
#          'people': 3407,
#          'frequently': 132,
#          'get': 5349,
#          'flamed': 18,
#          'for': 27955,
#          "announcing\n>they've": 1,
#          'got': 1723,
#          'new': 3532,
#          'book': 542,
#          'out.)\n>\n>i': 1,
#          "don't": 5103,
#          'know': 4368,
#          'whether': 727,
#          'an': 9029,
#          'official': 146,
#          'rule': 174,
#          'or': 12946,
#          'long-\n>standing': 1,
#          'custom,': 2,
#          'and': 50315,
#          'it': 22481,
#          "doesn't": 1412,
#          'make': 2553,
#          'much': 2610,
#          'difference': 428,
#          'from': 9344,
#          'practical\n>point': 1,
#          'view.\n\n\n\tas': 1,
#          'matter': 385,
#          'fact': 684,
#          'd.j.,': 3,
#          'does': 3369,
#          'difference.\n\talmost': 1,
#          'half': 276,
#          'million': 217,
#          'users': 347,
#          'joined': 34,
#          'internet': 279,
#          'last': 1765,
#          'year,\n\tmany': 1,
#          'them': 2749,
#          'are': 15591,
#          'commercial': 286,
#          'businesses.': 7,
#          'ban': 79,
#          'commercial\n\tuse': 1,
#          'no': 5103,
#          'more.\n\n\tone': 1,
#          'should': 3293,
#          'breeding': 6,
#          'post': 882,
#          'material\n\ton': 1,
#          'account': 159,
#          'provided': 198,
#          'by': 9066,
#          'ones': 264,
#          'employer': 56,
#          'school,': 65,
#          'unless': 493,
#          'the\n\tprovider': 1,
#          'such': 1877,
#          'gives': 348,
#          'permission.': 8,
#          '(ha!)\n\n\tthose': 1,
#          'us': 1630,
#          'who': 4925,
#          'pay': 452,
#          'access': 886,
#          'constrained': 12,
#          'only\n\tby': 1,
#          'our': 1810,
#          'innate': 5,
#          'good': 2985,
#          'taste': 68,
#          '"administrator"': 2,
#          '\n\tguide(?)': 1,
#          'us.\n\n\tjack': 1,
#          'previdi': 1,
#          'veni,': 1,
#          'vidi,': 1,
#          'fece!\n\tp00020@psilink.com\n\n': 1,
#          'xz775327@longs.lance.colostate.edu': 3,
#          '(xia': 3,
#          'zhao)\nsubject:': 9,
#          'more': 4955,
#          'radiosity\nnntp-posting-host:': 1,
#          'zirkel.lance.colostate.edu\norganization:': 1,
#          'colorado': 224,
#          'state': 1469,
#          'u.': 133,
#          'engineering': 398,
#          'college\nkeywords:': 1,
#          'radiosity\nlines:': 1,
#          '45\n\n\n\nin': 1,
#          '<1993apr19.131239.11670@aragorn.unibe.ch>,': 3,
#          'you': 20407,
#          'write:\n|>\n|>\n|>': 1,
#          "let's": 272,
#          'serious...': 4,
#          "i'm": 3097,
#          'working': 521,
#          'radiosity': 25,
#          'package,': 51,
#          'written': 437,
#          'c++.\n|>': 1,
#          'i': 35845,
#          'would': 8131,
#          'like': 5535,
#          'public': 828,
#          'domain.': 10,
#          "i'll": 730,
#          'announce': 47,
#          'c.g.': 4,
#          'minute\n|>': 1,
#          'finished': 88,
#          'it.\n|>\n|>': 1,
#          'that': 30458,
#          'were': 3901,
#          'news.': 44,
#          'bad': 713,
#          'news:': 12,
#          "it'll": 75,
#          'take': 1595,
#          'another': 1301,
#          '2': 3022,
#          'months': 358,
#          '(at': 190,
#          'least)\n|>': 1,
#          'finish': 108,
#          'it.\n\n\n': 6,
#          'using': 1864,
#          'traditional': 63,
#          'method,': 11,
#          'progressive': 15,
#          'refinement,': 3,
#          'or\n': 96,
#          'something': 1543,
#          'else': 730,
#          'package?\n\n': 2,
#          'if': 11623,
#          'need': 2464,
#          'project': 313,
#          'patches': 73,
#          'hemi-cube': 2,
#          'surfaces,': 11,
#          'what': 7189,
#          'technique': 78,
#          'are\n': 108,
#          'using?': 3,
#          'do': 7012,
#          'hardware': 406,
#          'facilitate': 15,
#          'projection?\n\n\n|>\n|>': 1,
#          'meantime': 7,
#          'may': 3052,
#          'look': 1346,
#          'at': 10484,
#          'file\n|>': 3,
#          'radiosity_code.tar.z\n|>': 1,
#          'located': 83,
#          'at\n|>': 7,
#          'compute1.cc.ncsu.edu\n\n\n': 1,
#          'guest': 25,
#          'username': 16,
#          'password': 25,
#          'ftp': 637,
#          'site?\n\n\n|>\n|>': 1,
#          '(there': 48,
#          'some': 5716,
#          'other': 4213,
#          'locations;': 3,
#          'archie': 39,
#          'nearest)\n|>\n|>': 1,
#          'hope': 541,
#          "that'll": 9,
#          'help.\n|>\n|>': 1,
#          'yours\n|>\n|>': 1,
#          'stephan\n|>\n\n\n': 1,
#          'thanks,': 23,
#          'stephan.\n\n\n': 1,
#          'josephine\n': 1,
#          'agallagh@slate.mines.colorado.edu': 4,
#          '(gallagher': 4,
#          'andrea': 7,
#          'j': 272,
#          ')\nsubject:': 77,
#          'detecting': 29,
#          'read-only': 15,
#          'colorcells?\nreply-to:': 1,
#          'ngorelic@speclab.cr.usgs.gov\norganization:': 2,
#          'school': 474,
#          'mines\nlines:': 3,
#          '27\n\n[again,': 1,
#          'poseted': 1,
#          'friend]\n\nokay,': 2,
#          'great': 978,
#          'response': 290,
#          'question': 1073,
#          '(thanks,': 3,
#          'everyone),': 1,
#          '\nlets': 1,
#          'try': 1063,
#          'again:\n\nhow': 1,
#          'can': 9280,
#          'tell': 1120,
#          'colorcell': 5,
#          'read-only?\n\ni': 1,
#          'want': 2223,
#          'any': 6412,
#          'cells': 65,
#          'already': 592,
#          'colormap\nonce': 1,
#          'start': 719,
#          'running': 891,
#          'out': 4949,
#          'allocatable': 1,
#          'cells,': 10,
#          'arbitrary\nnearest': 1,
#          'color': 753,
#          'matching': 22,
#          'scheme': 39,
#          'those': 2351,
#          'come': 1216,
#          'closest': 43,
#          'to\na': 27,
#          'requested': 41,
#          'color.\n\nonce': 1,
#          'determine': 144,
#          'cell': 70,
#          'read-only,': 1,
#          'assume': 315,
#          'then': 2925,
#          'request\nan': 1,
#          'xalloccolor()': 1,
#          'with': 16787,
#          'exact': 157,
#          'same': 2056,
#          'specifications': 16,
#          'will': 8123,
#          '\nthen': 17,
#          'flagged': 2,
#          'as': 13238,
#          "'used'": 1,
#          'application': 512,
#          'so': 5416,
#          'later': 308,
#          'get\nfreed': 1,
#          'someone': 1408,
#          'allocated': 25,
#          'again': 360,
#          'read-write': 1,
#          'another\napplication.\n\nso': 1,
#          'far,': 83,
#          'only': 4180,
#          'way': 2037,
#          "i've": 1674,
#          'figured': 69,
#          'write': 578,
#          'own\nerror': 1,
#          'handler': 56,
#          'go': 1972,
#          'ahead': 154,
#          'request': 173,
#          'colors,': 35,
#          'once': 609,
#          'my\ncolormap': 1,
#          'all': 7072,
#          'full': 622,
#          'up.': 262,
#          'error': 382,
#          'non-shareable.\nbut': 1,
#          'life': 625,
#          'easier': 156,
#          'could': 2967,
#          'detect': 45,
#          'the\nread-only/shareable': 1,
#          'stuff': 422,
#          'directly...\n\nany': 1,
#          'ideas?\n\nnoel': 1,
#          '(ngorelic@speclab.cr.usgs.gov)\n': 2,
#          'markm@bigfoot.sps.mot.com': 8,
#          '(mark': 436,
#          'monninger)\nsubject:': 8,
#          'car': 1140,
#          'buying': 288,
#          'story,': 52,
#          'was:': 29,
#          'christ,': 85,
#          'dealer': 269,
#          'service': 337,
#          'scam...\nnntp-posting-host:': 5,
#          '223.250.10.7\nreply-to:': 7,
#          'rapw20@email.sps.mot.com\norganization:': 7,
#          'sps\ndistribution:': 7,
#          'usa\nlines:': 839,
#          '28\n\nin': 77,
#          '<1993apr15.234508.20032@slcs.slb.com>': 1,
#          '\ndcd@se.houston.geoquest.slb.com': 2,
#          '(dan': 160,
#          'day)': 23,
#          'writes:\n>': 1004,
#          '...(relates': 1,
#          'experience': 416,
#          'similar': 522,
#          'mine)': 5,
#          '...\n>': 39,
#          'comes': 660,
#          'part': 1132,
#          'wish': 228,
#          'videotaped.': 2,
#          'we': 5642,
#          'out\n>': 20,
#          'front': 464,
#          'door,': 22,
#          'sales': 142,
#          'manager': 395,
#          'shouts': 3,
#          'across': 229,
#          'entire': 234,
#          'showroom,\n>': 1,
#          'customers': 42,
#          'all,': 285,
#          '"go': 17,
#          'ahead!': 3,
#          'deserve': 83,
#          'buy': 759,
#          'nissan!"\n>': 1,
#          'friend': 363,
#          'bought': 417,
#          'sentra.\n>': 1,
#          '...\n\nthis': 1,
#          'kind': 719,
#          'behavior': 92,
#          'was': 11595,
#          'shocked': 18,
#          "'experience'.": 2,
#          '\ncrying': 1,
#          'loud,': 9,
#          'how': 4304,
#          'these': 3020,
#          'turkeys': 5,
#          'think': 3817,
#          'they': 9344,
#          'talk': 340,
#          '\nthis': 134,
#          'still': 1731,
#          'stay': 234,
#          'business?': 3,
#          'again,': 274,
#          'expect': 390,
#          '\nbow,': 1,
#          'scrape,': 2,
#          'grovel': 2,
#          'presence': 74,
#          'but': 11901,
#          'sure': 1333,
#          '\nabused': 1,
#          'either.': 114,
#          'very': 2939,
#          'surprised': 112,
#          'talked': 95,
#          '\nme': 10,
#          "'negotiating'": 2,
#          'sessions': 31,
#          'overheard': 4,
#          'neighboring': 3,
#          '\ncubicles.': 1,
#          'evidently,': 5,
#          'their': 3964,
#          'success': 102,
#          'rate': 333,
#          'high': 847,
#          'enough': 1009,
#          'continue': 176,
#          '\nto': 271,
#          'business': 203,
#          'way.': 185,
#          'there': 6572,
#          'must': 1423,
#          'lot': 1146,
#          '\neasy': 2,
#          'intimidate.\n\non': 1,
#          'hand,': 205,
#          'about': 7414,
#          "'one": 1,
#          'price,': 47,
#          "haggling'": 1,
#          '\napproach': 4,
#          'saturn': 120,
#          'starting': 268,
#          'use.': 89,
#          'guess': 516,
#          'fixed': 129,
#          '\nprice': 3,
#          'fair': 155,
#          "it's": 3216,
#          'ok.': 53,
#          'maybe': 808,
#          'best': 1325,
#          'approach': 160,
#          'homework': 7,
#          '\nbefore': 20,
#          'in.': 157,
#          'find': 1817,
#          'invoice': 8,
#          'prices': 162,
#          'car,': 159,
#          'add': 482,
#          'reasonable': 234,
#          '\nprofit': 2,
#          '($200-$300??),': 3,
#          'offer': 286,
#          'price': 620,
#          'stick': 178,
#          '\nit.': 7,
#          'abusive,': 4,
#          'leave.': 4,
#          'then,': 175,
#          'screw': 65,
#          '\nafter': 27,
#          'deal': 397,
#          'agreed': 52,
#          'on.\n\nmark\n': 1,
#          'dwarf@bcarh601.bnr.ca': 3,
#          '(w.': 6,
#          'jim': 178,
#          'jordan)\nsubject:': 2,
#          'truly': 131,
#          'sad': 78,
#          'day': 703,
#          'hockey\nnntp-posting-host:': 1,
#          'bcarh601\norganization:': 2,
#          'bell-northern': 53,
#          'research': 945,
#          'ltd.,': 31,
#          'ottawa,': 74,
#          'ontario,': 96,
#          'canada\nlines:': 229,
#          '19\n\nfarewell,': 1,
#          'minnesota': 113,
#          'fans.': 28,
#          'stuffed,': 1,
#          'dallas': 40,
#          'stars.\n\nas': 1,
#          'north': 377,
#          'stars': 125,
#          'fade': 17,
#          'black,': 24,
#          'minneapolis/st.': 2,
#          'paul': 414,
#          'are\nnot': 26,
#          'long': 1085,
#          'without': 1433,
#          'nhl': 346,
#          'team.': 105,
#          'seems': 1184,
#          '"right"': 13,
#          'hotbed': 2,
#          'of\namateur': 1,
#          'hockey': 604,
#          'usa': 281,
#          'team': 1078,
#          'well.': 255,
#          'loss': 194,
#          'of\nthe': 337,
#          'certainly': 466,
#          'fault': 130,
#          'fans': 308,
#          '(though': 87,
#          'the\n1989-90': 1,
#          'season': 329,
#          'made': 1289,
#          'real': 884,
#          'while).\n\ni': 1,
#          'now': 1667,
#          'kept': 196,
#          'cap': 38,
#          'maple': 73,
#          'leaf\ngardens': 1,
#          'morning': 95,
#          'after': 2047,
#          'eliminated': 27,
#          'montreal': 118,
#          '1980.': 9,
#          '(i': 786,
#          'it\nto': 9,
#          'spite': 26,
#          'small': 666,
#          'town': 72,
#          'where': 2254,
#          'grew': 41,
#          'up.)': 3,
#          'a\nglorious': 1,
#          'stars!\n\n': 2,
#          'dwarf\n--\nw.': 2,
#          'jordan': 22,
#          '"i': 276,
#          'mean': 759,
#          'live\ndwarf@x400gate.bnr.ca': 2,
#          '(internet)': 12,
#          "life--that's": 2,
#          "tv's": 7,
#          'for--\ni': 2,
#          'work': 1548,
#          'bnr;': 2,
#          'speak': 381,
#          'it.': 1455,
#          "didn't": 1188,
#          'believe': 1550,
#          'jesus,': 60,
#          "i'd\n": 3,
#          'going': 1629,
#          'hell."': 2,
#          '-': 10315,
#          'peter': 216,
#          'heath\n': 2,
#          'manes@magpie.linknet.com': 28,
#          '(steve': 312,
#          'manes)\nsubject:': 8,
#          'gun': 901,
#          'control': 636,
#          '(was': 346,
#          "we're": 285,
#          'mad': 53,
#          'hell': 411,
#          'tv': 253,
#          'news)\norganization:': 7,
#          'manes': 10,
#          'associates,': 30,
#          'nyc\nx-newsreader:': 8,
#          'tin': 661,
#          '[version': 531,
#          '1.1': 663,
#          'pl9]\nlines:': 64,
#          '24\n\nj.': 1,
#          'spencer': 80,
#          '(j.m.spencer@newcastle.ac.uk)': 1,
#          'wrote:\n:': 197,
#          'manes)': 20,
#          'writes:\n\n:': 24,
#          '>jim': 1,
#          'de': 311,
#          'arras': 6,
#          '(jmd@cube.handheld.com)': 4,
#          '>:': 73,
#          '>': 1483,
#          'year': 1073,
#          'suffered': 51,
#          'almost': 580,
#          '10,000': 34,
#          'wrongful': 5,
#          'accidental\n:': 2,
#          'deaths': 125,
#          'handguns': 58,
#          'alone': 145,
#          '(fbi': 4,
#          'statistics).': 6,
#          'year,': 249,
#          'uk\n:': 2,
#          '35': 139,
#          '(scotland': 3,
#          'yard': 30,
#          'population\n:': 3,
#          'uk': 117,
#          '1/5': 5,
#          '(10,000': 4,
#          '/': 1984,
#          '(35': 6,
#          '*': 2553,
#          '5)).': 3,
#          'weighted\n:': 2,
#          'population,': 15,
#          'has': 6891,
#          '57x': 6,
#          'many': 2316,
#          'handgun-related': 3,
#          'the\n:': 70,
#          'uk.': 28,
#          'and,': 172,
#          'no,': 151,
#          'brits': 7,
#          'up': 4318,
#          'murdering': 6,
#          'as\n:': 5,
#          'baseball': 460,
#          'bats.\n\n:': 2,
#          '[snip]\n\n:': 1,
#          'examine': 46,
#          'figures,': 9,
#          'do.': 134,
#          'stabbing': 5,
#          'favourite,': 2,
#          'closely\n:': 1,
#          'followed': 149,
#          'striking,': 2,
#          'punching,': 2,
#          'kicking.': 2,
#          'burnt': 16,
#          'to\n:': 30,
#          'death': 284,
#          'britain': 21,
#          'shot': 249,
#          'death.': 37,
#          "you'll": 341,
#          'see': 2504,
#          'for\n:': 10,
#          'yourself.': 49,
#          '\n\nit': 49,
#          'means': 660,
#          'few': 1442,
#          'britain.\n--': 1,
#          '\nstephen': 15,
#          'manes\t\t\t\t\t': 10,
#          'manes@magpie.linknet.com\nmanes': 8,
#          'associates\t\t\t\t': 10,
#          'york,': 99,
#          'ny,': 25,
#          '=o&>o\n\n': 8,
#          'mhollowa@ic.sunysb.edu': 9,
#          '(michael': 512,
#          'holloway)\nsubject:': 6,
#          'transplant': 22,
#          'recipients': 11,
#          'newsletter,': 6,
#          'april': 710,
#          '`93[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[dinternational': 1,
#          '`93\nnntp-posting-host:': 1,
#          'engws5.ic.sunysb.edu\norganization:': 4,
#          'university': 4100,
#          'york': 328,
#          'stony': 27,
#          'brook\nlines:': 19,
#          '180\n\nthis': 1,
#          'monthly': 61,
#          'postings': 99,
#          'newsletter': 149,
#          '\nthe': 790,
#          'island': 38,
#          'chapter': 81,
#          '\ninternational': 6,
#          'organization': 129,
#          '(trio).': 1,
#          'unfortunately,': 107,
#          'before': 1407,
#          'date': 196,
#          "month's": 5,
#          'meeting.': 10,
#          '\nposting': 4,
#          'anyway,': 143,
#          'posting': 445,
#          'world-wide': 7,
#          'instead': 487,
#          '\nregional,': 1,
#          'hopes': 29,
#          'information': 1285,
#          '\nuseful': 3,
#          'illustrative.': 1,
#          'also,': 425,
#          'used': 2112,
#          '\nexample': 4,
#          'inspiration': 9,
#          'newsletters': 4,
#          '\nand': 315,
#          'data': 1341,
#          'related': 274,
#          'organ': 15,
#          'transplantation': 4,
#          'donation.': 2,
#          '\n\nmike\n\ntransplant': 1,
#          'recipients\ninternational': 1,
#          'organization\nlong': 1,
#          'chapter\np.o.': 1,
#          'box': 577,
#          '922\nhuntington,': 1,
#          'ny': 269,
#          '11743-0922\t\t': 1,
#          'newsletter\n516/421-3258\n': 1,
#          '\n': 7022,
#          'volume': 198,
#          'iv': 39,
#          'no.': 184,
#          '8\n\n\nnext': 1,
#          'meeting\n\n\nthe': 1,
#          'next': 984,
#          'meeting': 62,
#          'wednesday': 31,
#          '14': 354,
#          '8': 860,
#          'pm': 79,
#          'knights': 13,
#          '\nof': 245,
#          'columbus': 32,
#          'emerald': 1,
#          'manor,': 8,
#          '517': 4,
#          'uniondale': 3,
#          'avenue': 34,
#          'uniondale.': 1,
#          '\nour': 13,
#          'speaker': 61,
#          'dr.': 271,
#          'lewis': 91,
#          'teperman.': 2,
#          'teperman': 2,
#          '\ntrained': 1,
#          'pittsburgh': 241,
#          'under': 1332,
#          'starzl': 3,
#          'assistant': 39,
#          '\ndirector': 3,
#          'liver': 63,
#          'program': 1366,
#          '\nmedical': 14,
#          'center.': 25,
#          'discuss': 120,
#          'current': 598,
#          'trends': 15,
#          '\ntransplantation': 1,
#          'treatment': 177,
#          'answer': 507,
#          'questions.': 43,
#          '\na': 210,
#          'time': 2402,
#          'trio,': 1,
#          'surgeon': 18,
#          'members,': 13,
#          '\nalways': 6,
#          'gracious': 11,
#          'delightful': 2,
#          'guest.': 3,
#          '\nvery': 24,
#          'informative,': 2,
#          'interesting': 337,
#          'engaging': 9,
#          'evening.': 3,
#          '\nhospitality': 1,
#          'committee,': 9,
#          'bette': 2,
#          'vito': 2,
#          'suglia': 1,
#          'spence': 13,
#          '\nwill': 57,
#          'well': 1390,
#          'prepared,': 2,
#          'weather': 80,
#          '\ncooperative.': 1,
#          'large': 663,
#          'gathering': 21,
#          'welcome': 84,
#          '\ndr.': 3,
#          '\n\n': 678,
#          'k': 112,
#          'c': 632,
#          'uniondale\n\n\nlast': 1,
#          'meeting\n\nit': 1,
#          'been': 4031,
#          'noted': 93,
#          'here': 1211,
#          '\ntrio': 1,
#          'extraordinary': 13,
#          'power': 1066,
#          'predicting': 27,
#          'weather,': 8,
#          'being': 1909,
#          '\nable': 8,
#          'forecast': 24,
#          'rain,': 4,
#          'sleet': 1,
#          'snow': 47,
#          'fully': 194,
#          'month': 157,
#          'advance.': 27,
#          '\nno': 31,
#          'weatherman': 2,
#          'match': 122,
#          'us.': 130,
#          'scored': 148,
#          '\nagain,': 3,
#          'also': 3533,
#          'able': 988,
#          'disable': 33,
#          '\nrailroad,': 1,
#          'making': 501,
#          'travel': 44,
#          'really': 1937,
#          'difficult.': 13,
#          'none': 245,
#          'less,': 18,
#          '\nbraved': 1,
#          'had': 4393,
#          '\nconversation.': 1,
#          'scheduled': 107,
#          'speaker,': 11,
#          'mrs.': 9,
#          'elizabeth': 56,
#          'linnehan,': 1,
#          'professional': 110,
#          'nutritionist,': 2,
#          'family': 187,
#          'emergency': 53,
#          'attend.': 1,
#          'she': 932,
#          'fall': 178,
#          '\ndiscuss': 2,
#          'diet': 152,
#          'medications.': 2,
#          'however,': 826,
#          'ms.': 15,
#          'jennifer': 8,
#          'friedman,': 2,
#          '\nan': 29,
#          'image': 1171,
#          'consultant': 31,
#          'sister': 36,
#          'recipient': 6,
#          '\nwas': 54,
#          'step': 133,
#          'short': 339,
#          'notice.': 12,
#          'friedman': 24,
#          '\ngave': 2,
#          'advice': 285,
#          'choosing': 37,
#          'clothes': 29,
#          'makeup,': 1,
#          '\n(even': 2,
#          'bit': 934,
#          'men)': 1,
#          'help': 1426,
#          'healthy': 58,
#          '\nminimize': 1,
#          'cosmetic': 8,
#          'effects': 183,
#          'medicine': 133,
#          'drugs': 133,
#          'take.': 3,
#          'most': 2352,
#          'grateful': 60,
#          'thank': 206,
#          '\nher': 6,
#          'entertaining': 14,
#          'evening.\n\n\n\nannual': 1,
#          'meeting\n\nin': 1,
#          'addition': 132,
#          'welcoming': 1,
#          'teperman,': 1,
#          '\nalso': 40,
#          'annual': 168,
#          'chapter.': 1,
#          '\nnotice': 2,
#          'required': 247,
#          'by-laws.': 2,
#          'main': 331,
#          '\npurpose': 1,
#          'review': 142,
#          'past': 365,
#          'solicit': 6,
#          '\nmember': 3,
#          'views': 165,
#          'ideas': 211,
#          'better': 1501,
#          'ways': 152,
#          'meet': 183,
#          'needs,': 18,
#          'elect': 19,
#          'members': 223,
#          'board': 398,
#          'directors': 8,
#          'coming': 345,
#          'two': 2468,
#          '\nyear': 6,
#          'term.': 22,
#          'nominating': 4,
#          'committee': 83,
#          'prepared': 59,
#          'following': 862,
#          '\nslate': 1,
#          'board.\n\n': 1,
#          'anne': 14,
#          '(liver': 2,
#          'recipient)': 4,
#          'don': 169,
#          'treffeisen\n': 1,
#          'robert': 224,
#          '(heart': 1,
#          'eulene': 1,
#          'smith\n': 18,
#          '(kidney': 7,
#          'suglia\n': 1,
#          'kay': 9,
#          'grenzig': 1,
#          'recipient)\n': 6,
#          'jan': 57,
#          'schichtel': 1,
#          'larry': 92,
#          'juliano': 1,
#          'david': 417,
#          'bekofsky': 1,
#          '(director': 1,
#          'education': 145,
#          'litp)\n\nthose': 1,
#          'remaining': 47,
#          'are:\n\n': 15,
#          'carroll': 14,
#          '(liver,': 1,
#          'kidney': 89,
#          '&': 1979,
#          'pancreas': 2,
#          'jerry': 33,
#          'jeanne': 5,
#          'eichhorn\n': 1,
#          'ron': 172,
#          'donor)': 1,
#          'marie': 11,
#          'healy\n': 1,
#          'smith': 170,
#          '(bone': 1,
#          'marrow': 4,
#          'patricia': 2,
#          'ann': 68,
#          'yankus': 1,
#          'walter': 22,
#          'ruzak': 1,
#          'recipient)\n\nthis': 1,
#          'seem': 841,
#          'big': 801,
#          'board,': 55,
#          'hands': 160,
#          'light': 416,
#          'various': 382,
#          'medical': 601,
#          ...})

# %%
total_words
# Out:
# 434897

# %% [markdown]
# ### 建立一個單詞映射到索引的字典

# %%
def get_word_2_index(vocab):
    word2index = {}
    for i,word in enumerate(vocab):
        word2index[word.lower()] = i

    return word2index

word2index = get_word_2_index(vocab)
word2index
# Out:
# {'from:': 0,
#  '"jack': 1,
#  'previdi"': 2,
#  '<p00020@psilink.com>\nsubject:': 3,
#  're:': 4,
#  'printing\nin-reply-to:': 5,
#  '<1qk2m5$1up@agate.berkeley.edu>\nnntp-posting-host:': 6,
#  '127.0.0.1\norganization:': 7,
#  'avoirdupois': 8,
#  'institute\nx-mailer:': 9,
#  'psilink-dos': 10,
#  '(3.4)\nlines:': 11,
#  '38\n\n>date:': 12,
#  '': 13,
#  '15': 14,
#  'apr': 15,
#  '1993': 16,
#  '16:32:05': 17,
#  'gmt\n>from:': 18,
#  'cozzlab@garnet.berkeley.edu\n>\n>in': 19,
#  'article': 20,
#  '<1993apr15.053905.16811@sarah.albany.edu>': 21,
#  'me9574@albnyvms.bitnet': 22,
#  'writes:\n>\n>[advertises': 23,
#  'his': 24,
#  'printing': 25,
#  'business]\n>\n>oh,': 26,
#  'dear.': 27,
#  'let': 28,
#  'me': 29,
#  'be': 30,
#  'the': 31,
#  'first': 32,
#  'on': 33,
#  'my': 34,
#  'block.\n>\n>you': 35,
#  'have': 36,
#  'just': 37,
#  'violated': 38,
#  'one': 39,
#  'of': 40,
#  'major': 41,
#  'shibboleths': 42,
#  'usenet': 43,
#  'groups:\n': 44,
#  '^^^^^^^^^^^\n': 45,
#  '\tnit:': 46,
#  'is': 47,
#  'he': 48,
#  'unable': 49,
#  'to': 50,
#  'type': 51,
#  "'h'": 52,
#  'in': 53,
#  'this': 54,
#  'word?': 55,
#  ";-)\n\n>you're": 56,
#  'not': 57,
#  'supposed': 58,
#  'use': 59,
#  'a': 60,
#  'newsgroup': 61,
#  'plug': 62,
#  'your': 63,
#  'own': 64,
#  'commercial\n>enterprise': 65,
#  '(of': 66,
#  '_any_': 67,
#  'kind;': 68,
#  'people': 69,
#  'frequently': 70,
#  'get': 71,
#  'flamed': 72,
#  'for': 73,
#  "announcing\n>they've": 74,
#  'got': 75,
#  'new': 76,
#  'book': 77,
#  'out.)\n>\n>i': 78,
#  "don't": 79,
#  'know': 80,
#  'whether': 81,
#  'an': 82,
#  'official': 83,
#  'rule': 84,
#  'or': 85,
#  'long-\n>standing': 86,
#  'custom,': 87,
#  'and': 88,
#  'it': 89,
#  "doesn't": 90,
#  'make': 91,
#  'much': 92,
#  'difference': 93,
#  'from': 94,
#  'practical\n>point': 95,
#  'view.\n\n\n\tas': 96,
#  'matter': 97,
#  'fact': 98,
#  'd.j.,': 99,
#  'does': 100,
#  'difference.\n\talmost': 101,
#  'half': 102,
#  'million': 103,
#  'users': 104,
#  'joined': 105,
#  'internet': 106,
#  'last': 107,
#  'year,\n\tmany': 108,
#  'them': 109,
#  'are': 110,
#  'commercial': 111,
#  'businesses.': 112,
#  'ban': 113,
#  'commercial\n\tuse': 114,
#  'no': 115,
#  'more.\n\n\tone': 116,
#  'should': 117,
#  'breeding': 118,
#  'post': 119,
#  'material\n\ton': 120,
#  'account': 121,
#  'provided': 122,
#  'by': 123,
#  'ones': 124,
#  'employer': 125,
#  'school,': 126,
#  'unless': 127,
#  'the\n\tprovider': 128,
#  'such': 129,
#  'gives': 130,
#  'permission.': 131,
#  '(ha!)\n\n\tthose': 132,
#  'us': 133,
#  'who': 134,
#  'pay': 135,
#  'access': 136,
#  'constrained': 137,
#  'only\n\tby': 138,
#  'our': 139,
#  'innate': 140,
#  'good': 141,
#  'taste': 142,
#  '"administrator"': 143,
#  '\n\tguide(?)': 144,
#  'us.\n\n\tjack': 145,
#  'previdi': 146,
#  'veni,': 147,
#  'vidi,': 148,
#  'fece!\n\tp00020@psilink.com\n\n': 149,
#  'xz775327@longs.lance.colostate.edu': 150,
#  '(xia': 151,
#  'zhao)\nsubject:': 152,
#  'more': 153,
#  'radiosity\nnntp-posting-host:': 154,
#  'zirkel.lance.colostate.edu\norganization:': 155,
#  'colorado': 156,
#  'state': 157,
#  'u.': 158,
#  'engineering': 159,
#  'college\nkeywords:': 160,
#  'radiosity\nlines:': 161,
#  '45\n\n\n\nin': 162,
#  '<1993apr19.131239.11670@aragorn.unibe.ch>,': 163,
#  'you': 164,
#  'write:\n|>\n|>\n|>': 165,
#  "let's": 166,
#  'serious...': 167,
#  "i'm": 168,
#  'working': 169,
#  'radiosity': 170,
#  'package,': 171,
#  'written': 172,
#  'c++.\n|>': 173,
#  'i': 174,
#  'would': 175,
#  'like': 176,
#  'public': 177,
#  'domain.': 178,
#  "i'll": 179,
#  'announce': 180,
#  'c.g.': 181,
#  'minute\n|>': 182,
#  'finished': 183,
#  'it.\n|>\n|>': 184,
#  'that': 185,
#  'were': 186,
#  'news.': 187,
#  'bad': 188,
#  'news:': 189,
#  "it'll": 190,
#  'take': 191,
#  'another': 192,
#  '2': 193,
#  'months': 194,
#  '(at': 195,
#  'least)\n|>': 196,
#  'finish': 197,
#  'it.\n\n\n': 198,
#  'using': 199,
#  'traditional': 200,
#  'method,': 201,
#  'progressive': 202,
#  'refinement,': 203,
#  'or\n': 204,
#  'something': 205,
#  'else': 206,
#  'package?\n\n': 207,
#  'if': 208,
#  'need': 209,
#  'project': 210,
#  'patches': 211,
#  'hemi-cube': 212,
#  'surfaces,': 213,
#  'what': 214,
#  'technique': 215,
#  'are\n': 216,
#  'using?': 217,
#  'do': 218,
#  'hardware': 219,
#  'facilitate': 220,
#  'projection?\n\n\n|>\n|>': 221,
#  'meantime': 222,
#  'may': 223,
#  'look': 224,
#  'at': 225,
#  'file\n|>': 226,
#  'radiosity_code.tar.z\n|>': 227,
#  'located': 228,
#  'at\n|>': 229,
#  'compute1.cc.ncsu.edu\n\n\n': 230,
#  'guest': 231,
#  'username': 232,
#  'password': 233,
#  'ftp': 234,
#  'site?\n\n\n|>\n|>': 235,
#  '(there': 236,
#  'some': 237,
#  'other': 238,
#  'locations;': 239,
#  'archie': 240,
#  'nearest)\n|>\n|>': 241,
#  'hope': 242,
#  "that'll": 243,
#  'help.\n|>\n|>': 244,
#  'yours\n|>\n|>': 245,
#  'stephan\n|>\n\n\n': 246,
#  'thanks,': 247,
#  'stephan.\n\n\n': 248,
#  'josephine\n': 249,
#  'agallagh@slate.mines.colorado.edu': 250,
#  '(gallagher': 251,
#  'andrea': 252,
#  'j': 253,
#  ')\nsubject:': 254,
#  'detecting': 255,
#  'read-only': 256,
#  'colorcells?\nreply-to:': 257,
#  'ngorelic@speclab.cr.usgs.gov\norganization:': 258,
#  'school': 259,
#  'mines\nlines:': 260,
#  '27\n\n[again,': 261,
#  'poseted': 262,
#  'friend]\n\nokay,': 263,
#  'great': 264,
#  'response': 265,
#  'question': 266,
#  '(thanks,': 267,
#  'everyone),': 268,
#  '\nlets': 269,
#  'try': 270,
#  'again:\n\nhow': 271,
#  'can': 272,
#  'tell': 273,
#  'colorcell': 274,
#  'read-only?\n\ni': 275,
#  'want': 276,
#  'any': 277,
#  'cells': 278,
#  'already': 279,
#  'colormap\nonce': 280,
#  'start': 281,
#  'running': 282,
#  'out': 283,
#  'allocatable': 284,
#  'cells,': 285,
#  'arbitrary\nnearest': 286,
#  'color': 287,
#  'matching': 288,
#  'scheme': 289,
#  'those': 290,
#  'come': 291,
#  'closest': 292,
#  'to\na': 293,
#  'requested': 294,
#  'color.\n\nonce': 295,
#  'determine': 296,
#  'cell': 297,
#  'read-only,': 298,
#  'assume': 299,
#  'then': 300,
#  'request\nan': 301,
#  'xalloccolor()': 302,
#  'with': 303,
#  'exact': 304,
#  'same': 305,
#  'specifications': 306,
#  'will': 307,
#  '\nthen': 308,
#  'flagged': 309,
#  'as': 310,
#  "'used'": 311,
#  'application': 312,
#  'so': 313,
#  'later': 314,
#  'get\nfreed': 315,
#  'someone': 316,
#  'allocated': 317,
#  'again': 318,
#  'read-write': 319,
#  'another\napplication.\n\nso': 320,
#  'far,': 321,
#  'only': 322,
#  'way': 323,
#  "i've": 324,
#  'figured': 325,
#  'write': 326,
#  'own\nerror': 327,
#  'handler': 328,
#  'go': 329,
#  'ahead': 330,
#  'request': 331,
#  'colors,': 332,
#  'once': 333,
#  'my\ncolormap': 334,
#  'all': 335,
#  'full': 336,
#  'up.': 337,
#  'error': 338,
#  'non-shareable.\nbut': 339,
#  'life': 340,
#  'easier': 341,
#  'could': 342,
#  'detect': 343,
#  'the\nread-only/shareable': 344,
#  'stuff': 345,
#  'directly...\n\nany': 346,
#  'ideas?\n\nnoel': 347,
#  '(ngorelic@speclab.cr.usgs.gov)\n': 348,
#  'markm@bigfoot.sps.mot.com': 349,
#  '(mark': 350,
#  'monninger)\nsubject:': 351,
#  'car': 352,
#  'buying': 353,
#  'story,': 354,
#  'was:': 355,
#  'christ,': 356,
#  'dealer': 357,
#  'service': 358,
#  'scam...\nnntp-posting-host:': 359,
#  '223.250.10.7\nreply-to:': 360,
#  'rapw20@email.sps.mot.com\norganization:': 361,
#  'sps\ndistribution:': 362,
#  'usa\nlines:': 363,
#  '28\n\nin': 364,
#  '<1993apr15.234508.20032@slcs.slb.com>': 365,
#  '\ndcd@se.houston.geoquest.slb.com': 366,
#  '(dan': 367,
#  'day)': 368,
#  'writes:\n>': 369,
#  '...(relates': 370,
#  'experience': 371,
#  'similar': 372,
#  'mine)': 373,
#  '...\n>': 374,
#  'comes': 375,
#  'part': 376,
#  'wish': 377,
#  'videotaped.': 378,
#  'we': 379,
#  'out\n>': 380,
#  'front': 381,
#  'door,': 382,
#  'sales': 383,
#  'manager': 384,
#  'shouts': 385,
#  'across': 386,
#  'entire': 387,
#  'showroom,\n>': 388,
#  'customers': 389,
#  'all,': 390,
#  '"go': 391,
#  'ahead!': 392,
#  'deserve': 393,
#  'buy': 394,
#  'nissan!"\n>': 395,
#  'friend': 396,
#  'bought': 397,
#  'sentra.\n>': 398,
#  '...\n\nthis': 399,
#  'kind': 400,
#  'behavior': 401,
#  'was': 402,
#  'shocked': 403,
#  "'experience'.": 404,
#  '\ncrying': 405,
#  'loud,': 406,
#  'how': 407,
#  'these': 408,
#  'turkeys': 409,
#  'think': 410,
#  'they': 411,
#  'talk': 412,
#  '\nthis': 413,
#  'still': 414,
#  'stay': 415,
#  'business?': 416,
#  'again,': 417,
#  'expect': 418,
#  '\nbow,': 419,
#  'scrape,': 420,
#  'grovel': 421,
#  'presence': 422,
#  'but': 423,
#  'sure': 424,
#  '\nabused': 425,
#  'either.': 426,
#  'very': 427,
#  'surprised': 428,
#  'talked': 429,
#  '\nme': 430,
#  "'negotiating'": 431,
#  'sessions': 432,
#  'overheard': 433,
#  'neighboring': 434,
#  '\ncubicles.': 435,
#  'evidently,': 436,
#  'their': 437,
#  'success': 438,
#  'rate': 439,
#  'high': 440,
#  'enough': 441,
#  'continue': 442,
#  '\nto': 443,
#  'business': 444,
#  'way.': 445,
#  'there': 446,
#  'must': 447,
#  'lot': 448,
#  '\neasy': 449,
#  'intimidate.\n\non': 450,
#  'hand,': 451,
#  'about': 452,
#  "'one": 453,
#  'price,': 454,
#  "haggling'": 455,
#  '\napproach': 456,
#  'saturn': 457,
#  'starting': 458,
#  'use.': 459,
#  'guess': 460,
#  'fixed': 461,
#  '\nprice': 462,
#  'fair': 463,
#  "it's": 464,
#  'ok.': 465,
#  'maybe': 466,
#  'best': 467,
#  'approach': 468,
#  'homework': 469,
#  '\nbefore': 470,
#  'in.': 471,
#  'find': 472,
#  'invoice': 473,
#  'prices': 474,
#  'car,': 475,
#  'add': 476,
#  'reasonable': 477,
#  '\nprofit': 478,
#  '($200-$300??),': 479,
#  'offer': 480,
#  'price': 481,
#  'stick': 482,
#  '\nit.': 483,
#  'abusive,': 484,
#  'leave.': 485,
#  'then,': 486,
#  'screw': 487,
#  '\nafter': 488,
#  'deal': 489,
#  'agreed': 490,
#  'on.\n\nmark\n': 491,
#  'dwarf@bcarh601.bnr.ca': 492,
#  '(w.': 493,
#  'jim': 494,
#  'jordan)\nsubject:': 495,
#  'truly': 496,
#  'sad': 497,
#  'day': 498,
#  'hockey\nnntp-posting-host:': 499,
#  'bcarh601\norganization:': 500,
#  'bell-northern': 501,
#  'research': 502,
#  'ltd.,': 503,
#  'ottawa,': 504,
#  'ontario,': 505,
#  'canada\nlines:': 506,
#  '19\n\nfarewell,': 507,
#  'minnesota': 508,
#  'fans.': 509,
#  'stuffed,': 510,
#  'dallas': 511,
#  'stars.\n\nas': 512,
#  'north': 513,
#  'stars': 514,
#  'fade': 515,
#  'black,': 516,
#  'minneapolis/st.': 517,
#  'paul': 518,
#  'are\nnot': 519,
#  'long': 520,
#  'without': 521,
#  'nhl': 522,
#  'team.': 523,
#  'seems': 524,
#  '"right"': 525,
#  'hotbed': 526,
#  'of\namateur': 527,
#  'hockey': 528,
#  'usa': 529,
#  'team': 530,
#  'well.': 531,
#  'loss': 532,
#  'of\nthe': 533,
#  'certainly': 534,
#  'fault': 535,
#  'fans': 536,
#  '(though': 537,
#  'the\n1989-90': 538,
#  'season': 539,
#  'made': 540,
#  'real': 541,
#  'while).\n\ni': 542,
#  'now': 543,
#  'kept': 544,
#  'cap': 545,
#  'maple': 546,
#  'leaf\ngardens': 547,
#  'morning': 548,
#  'after': 549,
#  'eliminated': 550,
#  'montreal': 551,
#  '1980.': 552,
#  '(i': 553,
#  'it\nto': 554,
#  'spite': 555,
#  'small': 556,
#  'town': 557,
#  'where': 558,
#  'grew': 559,
#  'up.)': 560,
#  'a\nglorious': 561,
#  'stars!\n\n': 562,
#  'dwarf\n--\nw.': 563,
#  'jordan': 564,
#  '"i': 565,
#  'mean': 566,
#  'live\ndwarf@x400gate.bnr.ca': 567,
#  '(internet)': 568,
#  "life--that's": 569,
#  "tv's": 570,
#  'for--\ni': 571,
#  'work': 572,
#  'bnr;': 573,
#  'speak': 574,
#  'it.': 575,
#  "didn't": 576,
#  'believe': 577,
#  'jesus,': 578,
#  "i'd\n": 579,
#  'going': 580,
#  'hell."': 581,
#  '-': 582,
#  'peter': 583,
#  'heath\n': 584,
#  'manes@magpie.linknet.com': 585,
#  '(steve': 586,
#  'manes)\nsubject:': 587,
#  'gun': 588,
#  'control': 589,
#  '(was': 590,
#  "we're": 591,
#  'mad': 592,
#  'hell': 593,
#  'tv': 594,
#  'news)\norganization:': 595,
#  'manes': 596,
#  'associates,': 597,
#  'nyc\nx-newsreader:': 598,
#  'tin': 599,
#  '[version': 600,
#  '1.1': 601,
#  'pl9]\nlines:': 602,
#  '24\n\nj.': 603,
#  'spencer': 604,
#  '(j.m.spencer@newcastle.ac.uk)': 605,
#  'wrote:\n:': 606,
#  'manes)': 607,
#  'writes:\n\n:': 608,
#  '>jim': 609,
#  'de': 610,
#  'arras': 611,
#  '(jmd@cube.handheld.com)': 612,
#  '>:': 613,
#  '>': 614,
#  'year': 615,
#  'suffered': 616,
#  'almost': 617,
#  '10,000': 618,
#  'wrongful': 619,
#  'accidental\n:': 620,
#  'deaths': 621,
#  'handguns': 622,
#  'alone': 623,
#  '(fbi': 624,
#  'statistics).': 625,
#  'year,': 626,
#  'uk\n:': 627,
#  '35': 628,
#  '(scotland': 629,
#  'yard': 630,
#  'population\n:': 631,
#  'uk': 632,
#  '1/5': 633,
#  '(10,000': 634,
#  '/': 635,
#  '(35': 636,
#  '*': 637,
#  '5)).': 638,
#  'weighted\n:': 639,
#  'population,': 640,
#  'has': 641,
#  '57x': 642,
#  'many': 643,
#  'handgun-related': 644,
#  'the\n:': 645,
#  'uk.': 646,
#  'and,': 647,
#  'no,': 648,
#  'brits': 649,
#  'up': 650,
#  'murdering': 651,
#  'as\n:': 652,
#  'baseball': 653,
#  'bats.\n\n:': 654,
#  '[snip]\n\n:': 655,
#  'examine': 656,
#  'figures,': 657,
#  'do.': 658,
#  'stabbing': 659,
#  'favourite,': 660,
#  'closely\n:': 661,
#  'followed': 662,
#  'striking,': 663,
#  'punching,': 664,
#  'kicking.': 665,
#  'burnt': 666,
#  'to\n:': 667,
#  'death': 668,
#  'britain': 669,
#  'shot': 670,
#  'death.': 671,
#  "you'll": 672,
#  'see': 673,
#  'for\n:': 674,
#  'yourself.': 675,
#  '\n\nit': 676,
#  'means': 677,
#  'few': 678,
#  'britain.\n--': 679,
#  '\nstephen': 680,
#  'manes\t\t\t\t\t': 681,
#  'manes@magpie.linknet.com\nmanes': 682,
#  'associates\t\t\t\t': 683,
#  'york,': 684,
#  'ny,': 685,
#  '=o&>o\n\n': 686,
#  'mhollowa@ic.sunysb.edu': 687,
#  '(michael': 688,
#  'holloway)\nsubject:': 689,
#  'transplant': 690,
#  'recipients': 691,
#  'newsletter,': 692,
#  'april': 693,
#  '`93[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[d[dinternational': 694,
#  '`93\nnntp-posting-host:': 695,
#  'engws5.ic.sunysb.edu\norganization:': 696,
#  'university': 697,
#  'york': 698,
#  'stony': 699,
#  'brook\nlines:': 700,
#  '180\n\nthis': 701,
#  'monthly': 702,
#  'postings': 703,
#  'newsletter': 704,
#  '\nthe': 705,
#  'island': 706,
#  'chapter': 707,
#  '\ninternational': 708,
#  'organization': 709,
#  '(trio).': 710,
#  'unfortunately,': 711,
#  'before': 712,
#  'date': 713,
#  "month's": 714,
#  'meeting.': 715,
#  '\nposting': 716,
#  'anyway,': 717,
#  'posting': 718,
#  'world-wide': 719,
#  'instead': 720,
#  '\nregional,': 721,
#  'hopes': 722,
#  'information': 723,
#  '\nuseful': 724,
#  'illustrative.': 725,
#  'also,': 726,
#  'used': 727,
#  '\nexample': 728,
#  'inspiration': 729,
#  'newsletters': 730,
#  '\nand': 731,
#  'data': 732,
#  'related': 733,
#  'organ': 734,
#  'transplantation': 735,
#  'donation.': 736,
#  '\n\nmike\n\ntransplant': 737,
#  'recipients\ninternational': 738,
#  'organization\nlong': 739,
#  'chapter\np.o.': 740,
#  'box': 741,
#  '922\nhuntington,': 742,
#  'ny': 743,
#  '11743-0922\t\t': 744,
#  'newsletter\n516/421-3258\n': 745,
#  '\n': 746,
#  'volume': 747,
#  'iv': 748,
#  'no.': 749,
#  '8\n\n\nnext': 750,
#  'meeting\n\n\nthe': 751,
#  'next': 752,
#  'meeting': 753,
#  'wednesday': 754,
#  '14': 755,
#  '8': 756,
#  'pm': 757,
#  'knights': 758,
#  '\nof': 759,
#  'columbus': 760,
#  'emerald': 761,
#  'manor,': 762,
#  '517': 763,
#  'uniondale': 764,
#  'avenue': 765,
#  'uniondale.': 766,
#  '\nour': 767,
#  'speaker': 768,
#  'dr.': 769,
#  'lewis': 770,
#  'teperman.': 771,
#  'teperman': 772,
#  '\ntrained': 773,
#  'pittsburgh': 774,
#  'under': 775,
#  'starzl': 776,
#  'assistant': 777,
#  '\ndirector': 778,
#  'liver': 779,
#  'program': 780,
#  '\nmedical': 781,
#  'center.': 782,
#  'discuss': 783,
#  'current': 784,
#  'trends': 785,
#  '\ntransplantation': 786,
#  'treatment': 787,
#  'answer': 788,
#  'questions.': 789,
#  '\na': 790,
#  'time': 791,
#  'trio,': 792,
#  'surgeon': 793,
#  'members,': 794,
#  '\nalways': 795,
#  'gracious': 796,
#  'delightful': 797,
#  'guest.': 798,
#  '\nvery': 799,
#  'informative,': 800,
#  'interesting': 801,
#  'engaging': 802,
#  'evening.': 803,
#  '\nhospitality': 804,
#  'committee,': 805,
#  'bette': 806,
#  'vito': 807,
#  'suglia': 808,
#  'spence': 809,
#  '\nwill': 810,
#  'well': 811,
#  'prepared,': 812,
#  'weather': 813,
#  '\ncooperative.': 814,
#  'large': 815,
#  'gathering': 816,
#  'welcome': 817,
#  '\ndr.': 818,
#  '\n\n': 819,
#  'k': 820,
#  'c': 821,
#  'uniondale\n\n\nlast': 822,
#  'meeting\n\nit': 823,
#  'been': 824,
#  'noted': 825,
#  'here': 826,
#  '\ntrio': 827,
#  'extraordinary': 828,
#  'power': 829,
#  'predicting': 830,
#  'weather,': 831,
#  'being': 832,
#  '\nable': 833,
#  'forecast': 834,
#  'rain,': 835,
#  'sleet': 836,
#  'snow': 837,
#  'fully': 838,
#  'month': 839,
#  'advance.': 840,
#  '\nno': 841,
#  'weatherman': 842,
#  'match': 843,
#  'us.': 844,
#  'scored': 845,
#  '\nagain,': 846,
#  'also': 847,
#  'able': 848,
#  'disable': 849,
#  '\nrailroad,': 850,
#  'making': 851,
#  'travel': 852,
#  'really': 853,
#  'difficult.': 854,
#  'none': 855,
#  'less,': 856,
#  '\nbraved': 857,
#  'had': 858,
#  '\nconversation.': 859,
#  'scheduled': 860,
#  'speaker,': 861,
#  'mrs.': 862,
#  'elizabeth': 863,
#  'linnehan,': 864,
#  'professional': 865,
#  'nutritionist,': 866,
#  'family': 867,
#  'emergency': 868,
#  'attend.': 869,
#  'she': 870,
#  'fall': 871,
#  '\ndiscuss': 872,
#  'diet': 873,
#  'medications.': 874,
#  'however,': 875,
#  'ms.': 876,
#  'jennifer': 877,
#  'friedman,': 878,
#  '\nan': 879,
#  'image': 880,
#  'consultant': 881,
#  'sister': 882,
#  'recipient': 883,
#  '\nwas': 884,
#  'step': 885,
#  'short': 886,
#  'notice.': 887,
#  'friedman': 888,
#  '\ngave': 889,
#  'advice': 890,
#  'choosing': 891,
#  'clothes': 892,
#  'makeup,': 893,
#  '\n(even': 894,
#  'bit': 895,
#  'men)': 896,
#  'help': 897,
#  'healthy': 898,
#  '\nminimize': 899,
#  'cosmetic': 900,
#  'effects': 901,
#  'medicine': 902,
#  'drugs': 903,
#  'take.': 904,
#  'most': 905,
#  'grateful': 906,
#  'thank': 907,
#  '\nher': 908,
#  'entertaining': 909,
#  'evening.\n\n\n\nannual': 910,
#  'meeting\n\nin': 911,
#  'addition': 912,
#  'welcoming': 913,
#  'teperman,': 914,
#  '\nalso': 915,
#  'annual': 916,
#  'chapter.': 917,
#  '\nnotice': 918,
#  'required': 919,
#  'by-laws.': 920,
#  'main': 921,
#  '\npurpose': 922,
#  'review': 923,
#  'past': 924,
#  'solicit': 925,
#  '\nmember': 926,
#  'views': 927,
#  'ideas': 928,
#  'better': 929,
#  'ways': 930,
#  'meet': 931,
#  'needs,': 932,
#  'elect': 933,
#  'members': 934,
#  'board': 935,
#  'directors': 936,
#  'coming': 937,
#  'two': 938,
#  '\nyear': 939,
#  'term.': 940,
#  'nominating': 941,
#  'committee': 942,
#  'prepared': 943,
#  'following': 944,
#  '\nslate': 945,
#  'board.\n\n': 946,
#  'anne': 947,
#  '(liver': 948,
#  'recipient)': 949,
#  'don': 950,
#  'treffeisen\n': 951,
#  'robert': 952,
#  '(heart': 953,
#  'eulene': 954,
#  'smith\n': 955,
#  '(kidney': 956,
#  'suglia\n': 957,
#  'kay': 958,
#  'grenzig': 959,
#  'recipient)\n': 960,
#  'jan': 961,
#  'schichtel': 962,
#  'larry': 963,
#  'juliano': 964,
#  'david': 965,
#  'bekofsky': 966,
#  '(director': 967,
#  'education': 968,
#  'litp)\n\nthose': 969,
#  'remaining': 970,
#  'are:\n\n': 971,
#  'carroll': 972,
#  '(liver,': 973,
#  'kidney': 974,
#  '&': 975,
#  'pancreas': 976,
#  'jerry': 977,
#  'jeanne': 978,
#  'eichhorn\n': 979,
#  'ron': 980,
#  'donor)': 981,
#  'marie': 982,
#  'healy\n': 983,
#  'smith': 984,
#  '(bone': 985,
#  'marrow': 986,
#  'patricia': 987,
#  'ann': 988,
#  'yankus': 989,
#  'walter': 990,
#  'ruzak': 991,
#  'recipient)\n\nthis': 992,
#  'seem': 993,
#  'big': 994,
#  'board,': 995,
#  'hands': 996,
#  'light': 997,
#  'various': 998,
#  'medical': 999,
#  ...}

# %% [markdown]
# ### 建立批次訓練數據
#
# 基本上這裡是把每一條訓練文本分割後使用bag of words（BoW)的方式建立成一個含有單詞頻次的向量。然後對應著這個向量的是所屬分類主題類別

# %%
def get_batch(df, i, batch_size):
    batches = []
    results = []
    texts = df.data[i*batch_size:i*batch_size+batch_size]
    categories = df.target[i*batch_size:i*batch_size+batch_size]
    
    for text in texts:
        layer = np.zeros(total_words, dtype=float)
        for word in text.split(' '):
            layer[word2index[word.lower()]] += 1
        batches.append(layer)

    for category in categories:
        """
        index_y = -1
        if category == 0:
            index_y = 0
        elif category == 1:
            index_y = 1
        else:
            index_y = 2
        results.append(index_y)
        """
        results.append(category)

    return np.array(batches), np.array(results)

# %% [markdown]
# ### 基本訓練參數

# %%
# Parameters
learning_rate = 0.01
num_epochs = 2
batch_size = 150
display_step = 1

# Network Parameters
hidden_size = 100           # 1st layer and 2nd layer number of features
input_size = total_words    # Words in vocab
num_classes = len(categories)         
print('number of classes: %d' % num_classes)
# Out:
# number of classes: 14

# %%
#from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### 模型定義
#
# 簡單的fully connected layers with ReLu activation

# %%
class OurNet(nn.Module):
     def __init__(self, input_size, hidden_size, num_classes):
        super(OurNet, self).__init__()
        self.layer_1 = nn.Linear(input_size,hidden_size, bias=True)
        self.relu = nn.ReLU()
        self.layer_2 = nn.Linear(hidden_size, hidden_size, bias=True)
        self.output_layer = nn.Linear(hidden_size, num_classes, bias=True)

     def forward(self, x):
        out = self.layer_1(x)
        out = self.relu(out)
        out = self.layer_2(out)
        out = self.relu(out)
        out = self.output_layer(out)
        return out

# %% [markdown]
# ### 訓練廻圈

# %%
net = OurNet(input_size, hidden_size, num_classes)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss()  
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)  

# Train the Model
for epoch in range(num_epochs):
    total_batch = int(len(newsgroups_train.data)/batch_size)
    # Loop over all batches
    for i in range(total_batch):
        batch_x, batch_y = get_batch(newsgroups_train, i, batch_size)
        #articles = Variable(torch.FloatTensor(batch_x))
        #labels = Variable(torch.LongTensor(batch_y))
        articles = torch.FloatTensor(batch_x)
        labels = torch.LongTensor(batch_y)
        #print("articles",articles)
        #print(batch_x, labels)
        #print("size labels",labels.size())

        # Forward + Backward + Optimize
        optimizer.zero_grad()  # zero the gradient buffer
        outputs = net(articles)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i+1) % 4 == 0:
            print ('Epoch [%d/%d], Step [%d/%d], Loss: %.4f'
                   %(epoch+1, num_epochs, i+1, len(newsgroups_train.data)//batch_size, loss.data))
# Out:
# Epoch [1/2], Step [4/54], Loss: 2.5895
# Epoch [1/2], Step [8/54], Loss: 2.3218
# Epoch [1/2], Step [12/54], Loss: 1.9189
# Epoch [1/2], Step [16/54], Loss: 1.5746
# Epoch [1/2], Step [20/54], Loss: 1.1540
# Epoch [1/2], Step [24/54], Loss: 1.2092
# Epoch [1/2], Step [28/54], Loss: 0.9164
# Epoch [1/2], Step [32/54], Loss: 0.7724
# Epoch [1/2], Step [36/54], Loss: 0.7211
# Epoch [1/2], Step [40/54], Loss: 0.6619
# Epoch [1/2], Step [44/54], Loss: 0.5575
# Epoch [1/2], Step [48/54], Loss: 0.7289
# Epoch [1/2], Step [52/54], Loss: 0.5483
# Epoch [2/2], Step [4/54], Loss: 0.3211
# Epoch [2/2], Step [8/54], Loss: 0.2343
# Epoch [2/2], Step [12/54], Loss: 0.1787
# Epoch [2/2], Step [16/54], Loss: 0.5945
# Epoch [2/2], Step [20/54], Loss: 0.2380
# Epoch [2/2], Step [24/54], Loss: 0.1309
# Epoch [2/2], Step [28/54], Loss: 0.3651
# Epoch [2/2], Step [32/54], Loss: 0.1366
# Epoch [2/2], Step [36/54], Loss: 0.0562
# Epoch [2/2], Step [40/54], Loss: 0.1330
# Epoch [2/2], Step [44/54], Loss: 0.1916
# Epoch [2/2], Step [48/54], Loss: 0.0729
# Epoch [2/2], Step [52/54], Loss: 0.7866

# %%
# Test the Model
correct = 0
total = 0
total_test_data = len(newsgroups_test.target)

batch_x_test, batch_y_test = get_batch(newsgroups_test,0,total_test_data)
#articles = Variable(torch.FloatTensor(batch_x_test))
articles = torch.FloatTensor(batch_x_test)
labels = torch.LongTensor(batch_y_test)
net.eval()
with torch.no_grad():    
    outputs = net(articles)

print('output size: ')
print(outputs.data.size())
_, predicted = torch.max(outputs.data, 1)
print('correctly predicted: ')
print((predicted == labels).sum())

total += labels.size(0)
correct += (predicted == labels).sum()

accuracy = 100 * correct / total
print('Accuracy of the network on the %d test articles: %d %%' % (total, accuracy))
# Out:
# output size:
# torch.Size([5487, 14])
# correctly predicted:
# tensor(4209)
# Accuracy of the network on the 5487 test articles: 76 %
